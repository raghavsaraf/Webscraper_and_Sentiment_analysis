# %%
import time
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from urllib.request import urlopen as uReq
import numpy as np
import pandas as pd
import re
from urllib import request
import timeit
from textblob import TextBlob
import itertools

# %%
#Enter number of pages to get data from
n_pages=50
soups=[]

#Location of my chromedriver
driver=webdriver.Chrome('C:\Softwares\chromedriver_win32\chromedriver.exe')

url1="https://www.business-standard.com"

#Fetching the URL and printing its title
driver.get(url1)
print(driver.title)

#Identifying the search area using the specific 'id' present in the html version of the page

search_text=driver.find_element_by_xpath('(//*[@id="head-suggest"])')
search_text.send_keys("Indian tourists in UK")

#Button accessed using the inspecting feature of Chrome and then copying the Xpath of the button to be clicked

search_button=driver.find_element_by_xpath('(//*[@id="search_btn"]/input)')
search_button.click()


current_url=driver.current_url
soups.append(BeautifulSoup(driver.page_source,'html.parser'))

#Click on the 'next' button to go to next page, fetch its data and then store it in a soup list
while(n_pages!=0):
    if(n_pages==50):
        next_button=driver.find_element_by_xpath('(//*[@id="hpcontentbox"]/div[3]/div[2]/div[1]/div[2]/div/div[1]/a)')
    else:
        next_button=driver.find_element_by_xpath('(//*[@id="hpcontentbox"]/div[3]/div[2]/div[1]/div[2]/div/div[2]/a)')
        
    next_button.click()
    soups.append(BeautifulSoup(driver.page_source,'html.parser'))
    n_pages-=1
#Pause for 10 seconds
time.sleep(5)

#Quits the browsed page
driver.quit()
# Out:
# India News, Latest News Headlines, BSE live, NSE Live, Stock Markets Live, Financial News, Business News & Market Analysis on Indian Economy - Business Standard

# %% [markdown]
# ### Functions used are defined in the next cell

# %%
#This function separates the information on the basis of date, heading, topic, article description and link for the article 

def infoCollect(containers):
    links=[]
    heading=[]
    description=[]
    date=[]
    topic=[]
    for c in containers[0].find_all('li',{'class':''}):
        links.append(url1+c.find_all('a')[1]['href'])
        heading.append(c.find_all('a')[1].get_text())
        date.append(c.p.get_text().split('|')[0])
        topic.append(c.p.get_text().split('|')[1])
        if(len(c.find_all('p'))==2):
            description.append(c.find_all('p')[1].get_text())
        elif(len(c.find_all('p'))==4):
            description.append(c.find_all('p')[2].get_text())
    return date,heading,topic,links,description

#Content Fetch using the Links saved in infoCollect function

def findText(containers,links):
    #elements=int(len(containers[0].find_all('p'))/2)
    elements=19
    text=[]
    fintext=[]
    for i in range(0,elements):
        tempclient=uReq(l[i]) #Opens connection to website and downloads the page
        page_temp=tempclient.read() #Dont run this directly
        tempclient.close() #CLoses the page to prevent crashing of console
        temp_soup=BeautifulSoup(page_temp, "html.parser")
        cont=temp_soup.find_all("span",{'class':'p-content'})
        for x in cont[0].find_all("p",{"class":''}):
            [x.extract() for x in x.findAll('script')]
            text.append(x.get_text())
        x=' '.join(text)
        del text[:]
        fintext.append(x)
    return fintext

#Fetches the containers(only the part that we need) based on initial soup html for each page
def containerFetch(soup):
    #containers=soup.find_all('div',{'class':"listing-main topB mT10"})
    containers=[]
    for i in range(0,len(soup)-1):
        containers.append((soup[i]).find_all('div',{'class':'listing-main topB mT10'}))
    return containers

#Formats the output from infoCollect and finText

def listFormat(date,topic,links,description,fintext):
    #nhead=list(itertools.chain.from_iterable(heading))
    ndate=list(itertools.chain.from_iterable(date))
    ntopic=list(itertools.chain.from_iterable(topic))
    ndesc=list(itertools.chain.from_iterable(description))
    nfin=list(itertools.chain.from_iterable(fintext))
    for i in range(0,len(links)-1):
        if(len(links[i])>19):
            del links[i][-1]
    nlinks=list(itertools.chain.from_iterable(links))
    return ndate,ntopic,nlinks,ndesc,nfin

# %%
#Main Code
start_time = timeit.default_timer()
all_containers=containerFetch(soups)
#heading=[]
date=[]
topic=[]
links=[]
description=[]
fintext=[]
p_count=0
for i in range(0,len(all_containers)-1):
    start_time = timeit.default_timer()
    da,h,t,l,de=infoCollect(all_containers[i])
    ft=findText(all_containers[i],l)
    p_count+=1
    print("Page number :",p_count)
    #heading.append(h)
    date.append(da)
    topic.append(t)
    links.append(l)
    description.append(de)
    fintext.append(ft)
    elapsed = timeit.default_timer() - start_time
    print("Time taken for fetching page : ",elapsed)
    print('---------------------------------------')
elapsed = timeit.default_timer() - start_time
print(elapsed)
# Out:
# Page number : 1
# Time taken for fetching page :  19.879553377600388
# ---------------------------------------
# Page number : 2
# Time taken for fetching page :  18.65702781178462
# ---------------------------------------
# Page number : 3
# Time taken for fetching page :  16.507239096697262
# ---------------------------------------
# Page number : 4
# Time taken for fetching page :  19.37739160412694
# ---------------------------------------
# Page number : 5
# Time taken for fetching page :  21.655058322372767
# ---------------------------------------
# Page number : 6
# Time taken for fetching page :  28.462000573438857
# ---------------------------------------
# Page number : 7
# Time taken for fetching page :  24.30022254889022
# ---------------------------------------
# Page number : 8
# Time taken for fetching page :  23.55398972361158
# ---------------------------------------
# Page number : 9
# Time taken for fetching page :  21.75945150118099
# ---------------------------------------
# Page number : 10
# Time taken for fetching page :  18.5959195956801
# ---------------------------------------
# Page number : 11
# Time taken for fetching page :  19.511577434725837
# ---------------------------------------
# Page number : 12
# Time taken for fetching page :  16.53874978951154
# ---------------------------------------
# Page number : 13
# Time taken for fetching page :  18.60379982887855
# ---------------------------------------
# Page number : 14
# Time taken for fetching page :  17.436613388432022
# ---------------------------------------
# Page number : 15
# Time taken for fetching page :  18.67007980357448
# ---------------------------------------
# Page number : 16
# Time taken for fetching page :  17.38123330314437
# ---------------------------------------
# Page number : 17
# Time taken for fetching page :  25.884331465864477
# ---------------------------------------
# Page number : 18
# Time taken for fetching page :  24.1925178744533
# ---------------------------------------
# Page number : 19
# Time taken for fetching page :  22.858555730520152
# ---------------------------------------
# Page number : 20
# Time taken for fetching page :  20.7362380362905
# ---------------------------------------
# Page number : 21
# Time taken for fetching page :  18.94093864204217
# ---------------------------------------
# Page number : 22
# Time taken for fetching page :  16.796125419270254
# ---------------------------------------
# Page number : 23
# Time taken for fetching page :  18.010708743122166
# ---------------------------------------
# Page number : 24
# Time taken for fetching page :  17.90819516946027
# ---------------------------------------
# Page number : 25
# Time taken for fetching page :  16.671169223627487
# ---------------------------------------
# Page number : 26
# Time taken for fetching page :  24.082075143245902
# ---------------------------------------
# Page number : 27
# Time taken for fetching page :  21.306897308933344
# ---------------------------------------
# Page number : 28
# Time taken for fetching page :  21.694749052232964
# ---------------------------------------
# Page number : 29
# Time taken for fetching page :  21.065171781346862
# ---------------------------------------
# Page number : 30
# Time taken for fetching page :  21.249060197426843
# ---------------------------------------
# Page number : 31
# Time taken for fetching page :  17.00148309038036
# ---------------------------------------
# Page number : 32
# Time taken for fetching page :  16.219753375779987
# ---------------------------------------
# Page number : 33
# Time taken for fetching page :  16.08382845531048
# ---------------------------------------
# Page number : 34
# Time taken for fetching page :  16.051925798832258
# ---------------------------------------
# Page number : 35
# Time taken for fetching page :  16.99510301419491
# ---------------------------------------
# Page number : 36
# Time taken for fetching page :  28.387557059441974
# ---------------------------------------
# Page number : 37
# Time taken for fetching page :  23.630968201449946
# ---------------------------------------
# Page number : 38
# Time taken for fetching page :  19.112322336353827
# ---------------------------------------
# Page number : 39
# Time taken for fetching page :  18.436871094585626
# ---------------------------------------
# Page number : 40
# Time taken for fetching page :  16.54778941595714
# ---------------------------------------
# Page number : 41
# Time taken for fetching page :  17.187560586546056
# ---------------------------------------
# Page number : 42
# Time taken for fetching page :  20.556941113290577
# ---------------------------------------
# Page number : 43
# Time taken for fetching page :  17.561880196789616
# ---------------------------------------
# Page number : 44
# Time taken for fetching page :  18.90481085619888
# ---------------------------------------
# Page number : 45
# Time taken for fetching page :  28.666535632853538
# ---------------------------------------
# Page number : 46
# Time taken for fetching page :  23.235315300349953
# ---------------------------------------
# Page number : 47
# Time taken for fetching page :  18.729798226890694
# ---------------------------------------
# Page number : 48
# Time taken for fetching page :  16.528294201440872
# ---------------------------------------
# Page number : 49
# Time taken for fetching page :  22.176379097698486
# ---------------------------------------
# 22.1767141725868

# %%
ndate,ntopic,nlinks,ndesc,nfin=listFormat(date,topic,links,description,fintext)

# %%
#Combines the data based on date,topic,description,link for the article,content
combine={'Date':ndate,'Topic':ntopic,'Description':ndesc,'Link for website':nlinks,'Content':nfin}
data=pd.DataFrame(combine)
col=['Description','Content']
for c in col:
    data[c]=data[c].str.replace('\r',' ')
data.Content = data.Content.apply(lambda x:re.sub(' +',' ',x))
data.Content = data.Content.apply(lambda x:x.strip("/"))
data.Content = data.Content.apply(lambda x:x.strip())
data['Sentiment']=data['Content'].apply(lambda x:TextBlob(x).sentiment[0])

# %%
data.head()
# Out:
#                          Date              Topic  \
# 0   March 10, 2018, Saturday    Economy & Policy
# 1   October 09, 2017, Monday     Current Affairs
# 2    August 12, 2011, Friday    Economy & Policy
# 3     March 25, 2011, Friday    Economy & Policy
# 4  August 12, 2010, Thursday    Economy & Policy
#
#                                          Description  \
# 0  Said new UK-India Visa Agreement being propose...
# 1  China on Sunday referred to the 1890 UK-China ...
# 2  Indian travellers, both for leisure and busine...
# 3  Britain's tourism promotion board, Visit Brita...
# 4   Prime Minister David Cameron today said visa ...
#
#                                     Link for website  \
# 0  https://www.business-standard.com/article/econ...
# 1  https://www.business-standard.com/article/curr...
# 2  https://www.business-standard.com/article/econ...
# 3  https://www.business-standard.com/article/econ...
# 4  https://www.business-standard.com/article/econ...
#
#                                              Content  Sentiment
# 0  A leading UK-based think tank has released a r...   0.214417
# 1  Doklam and the Sikkim stretch of the border be...   0.045455
